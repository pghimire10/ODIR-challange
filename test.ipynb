# %%
from glob import glob
import os
import matplotlib.pyplot as plt
import numpy as np
from source.cropping import crop_nonzero
import matplotlib.pyplot as plt
import matplotlib.image as imgg

# %%
img = imgg.imread(r'ODIR-5K_Training_Images\ODIR-5K_Training_Dataset\6_right.jpg')
fig,ax = plt.subplots(1,2)
cropped_img = crop_nonzero(img)

ax[0].imshow(img)
ax[1].imshow(cropped_img)

plt.show()
